# %% [markdown]
# <a href="https://colab.research.google.com/github/jonnie763/DATA-Science-601-Intro-to-Data-Science/blob/main/Replication_Project_Draft_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #(3)

# %%
# prompt: generate dataframe with massachusetts rows only /content/sub-est00int.csv fix 'utf-8' codec

import pandas as pd

try:
    df = pd.read_csv('/content/sub-est00int.csv', encoding='utf-8')
except UnicodeDecodeError:
    try:
        df = pd.read_csv('/content/sub-est00int.csv', encoding='latin1')
    except UnicodeDecodeError:
         print("Could not decode the file with utf-8 or latin1 encodings.")
         exit()

# Filter for Massachusetts rows
df_mass = df[df['STNAME'] == 'Massachusetts']

df_mass
# Out:
#        SUMLEV  STATE  COUNTY  PLACE  COUSUB                 Municipality  \
# 28166      40     25       0      0       0                Massachusetts
# 28167     162     25       0    840       0             Agawam Town city
# 28168     162     25       0   1260       0           Amesbury Town city
# 28169     162     25       0   2690       0               Attleboro city
# 28170     162     25       0   3690       0         Barnstable Town city
# ...       ...    ...     ...    ...     ...                          ...
# 28697     157     25      27  63345       0        Southbridge Town city
# 28698      71     25      27  63345   63345        Southbridge Town city
# 28699     157     25      27  82000       0               Worcester city
# 28700      71     25      27  82000   82000               Worcester city
# 28701     157     25      27  99990       0  Balance of Worcester County
#
#               STNAME  ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001  \
# ...

# %%
# prompt: generate dataframe  /content/sub-est00int.csv fix 'utf-8' codec name it df_mass include all rows

try:
    df_mass = pd.read_csv('/content/sub-est00int.csv', encoding='utf-8')
except UnicodeDecodeError:
    try:
        df_mass = pd.read_csv('/content/sub-est00int.csv', encoding='latin1')
    except UnicodeDecodeError:
         print("Could not decode the file with utf-8 or latin1 encodings.")
         exit()

df_mass
# Out:
#        SUMLEV  STATE  COUNTY  PLACE  COUSUB                Municipality  \
# 0          40      1       0      0       0                     Alabama
# 1         162      1       0    124       0              Abbeville city
# 2         162      1       0    460       0             Adamsville city
# 3         162      1       0    484       0                Addison town
# 4         162      1       0    676       0                  Akron town
# ...       ...    ...     ...    ...     ...                         ...
# 81620     157     56      43  99990       0  Balance of Washakie County
# 81621      50     56      45      0       0               Weston County
# 81622     157     56      45  56215       0              Newcastle city
# 81623     157     56      45  79125       0                  Upton town
# 81624     157     56      45  99990       0    Balance of Weston County
#
#         STNAME  ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001  \
# ...

# %%
# prompt: generate dataframe /content/GenFundRevenues2005.dta

# !pip install pyreadstat
import pandas as pd
import pyreadstat

try:
  df, meta = pyreadstat.read_dta('/content/GenFundRevenues2005.dta')
except Exception as e:
  print(f"Error reading file: {e}")
  exit()

df
# Out:
# ...
#      DORCode Municipality FiscalYear         Taxes  ServiceCharges  \
# 0        001     Abington       2005  2.173005e+07          132145
# 1        002        Acton       2005  5.171327e+07          350724
# 2        003     Acushnet       2005  1.174438e+07          108920
# 3        004        Adams       2005  7.378683e+06          141878
# 4        005       Agawam       2005  4.185985e+07         1067972
# ..       ...          ...        ...           ...             ...
# 346      348    Worcester       2005  1.821909e+08         8060990
# 347      349  Worthington       2005  1.832777e+06           60380
# 348      350     Wrentham       2005  2.030321e+07          228063
# 349      351     Yarmouth       2005  4.104280e+07         4354998
# 350  Totals:                          9.093101e+09       458478301
#
#      LicensesandPermits  FederalRevenue  StateRevenue  \
# 0                461459          125218  9.292885e+06
# ...

# %%
merged_df = pd.merge(df_mass, df, on='Municipality')

merged_df
# Out:
#    SUMLEV  STATE  COUNTY  PLACE  COUSUB Municipality      STNAME  \
# 0      40     12       0      0       0      Florida     Florida
# 1      40     53       0      0       0   Washington  Washington
#
#    ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001  ...  \
# 0           15982571         16047515         16356966  ...
# 1            5894281          5910512          5985722  ...
#
#    LicensesandPermits  FederalRevenue  StateRevenue  \
# 0                5705               0      496750.0
# 1                2261            7961      146851.0
#
#    RevenuefromOtherGovernments  SpecialAssessments  FinesandForfeitures  \
# 0                            0                   0                  580
# 1                        12516                   0                    0
#
#    Miscellaneous  OtherFinancingSources  Transfers  TotalRevenues
# 0          13564                      0      37900      1913266.0
# 1           7466                      0      65000      1346394.0
#
# ...
